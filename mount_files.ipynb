# %%
def mount_container(container_name):
    source = f'wasbs://{container_name}@data0migration0p0dl.blob.core.windows.net'
    mount_point=f'/mnt/{container_name}'
    acc_key = dbutils.secrets.get(scope="acess_key_sA", key="storageAcessKey")
    return dbutils.fs.mount(
  source = source,
  mount_point = mount_point,
  extra_configs = {"fs.azure.account.key.data0migration0p0dl.blob.core.windows.net":acc_key})



# COMMAND ----------

mount_container('bronze')
mount_container('silver')
mount_container('gold')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# File <command-1260931212309757>:14
#       5     return dbutils.fs.mount(
#       6   source = source,
#       7   mount_point = mount_point,
#       8   extra_configs = {"fs.azure.account.key.data0migration0p0dl.blob.core.windows.net":acc_key})
#      12 # COMMAND ----------
# ---> 14 mount_container('bronze')
#      15 mount_container('silver')
#      16 mount_container('gold')
#
# File <command-1260931212309757>:4, in mount_container(container_name)
#       2   source = f'wasbs://{container_name}@data0migration0p0dl.blob.core.windows.net'
#       3   mount_point=f'/mnt/{container_name}'
# ----> 4   acc_key = dbutils.secrets.get(scope="acess_key_sA", key="storageAcessKey")
#       5   return dbutils.fs.mount(
#       6 source = source,
#       7 mount_point = mount_point,
# ...
